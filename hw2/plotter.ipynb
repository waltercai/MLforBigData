# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with open("/Users/waltercai/Documents/cse547/hw2/2DGaussianMixture.csv") as f:
    coord1 = []
    coord2 = []
    first_line = True
    for line in f:
        if first_line:
            first_line = False
        else:
            line_split = line.split(",")
            coord1.append(float(line_split[1]))
            coord2.append(float(line_split[2]))

# %%
centroids2 = [[0.9261249122748091, 0.22870630900763358],
[0.559900067932249, 0.753999823333333]]
centroids2_1 = [row[0] for row in centroids2]
centroids2_2 = [row[1] for row in centroids2]

centroids3 = [[0.41989432122685194, 0.7413268816342596],
[0.757555239751634, 0.7718910351437905],
[0.9261249122748091, 0.22870630900763358]]
centroids3_1 = [row[0] for row in centroids3]
centroids3_2 = [row[1] for row in centroids3]

centroids5 = [[0.8211214966969695, 0.19148122634848488],
[0.7586667374473685, 0.7718501141447366],
[0.4082205035833333, 0.6857256655333331],
[1.0327437650153846, 0.2665040852461539],
[0.4360754695360825, 0.8104911092371132]]
centroids5_1 = [row[0] for row in centroids5]
centroids5_2 = [row[1] for row in centroids5]

centroids10 = [[0.7925968313749998, 0.683711234275],
[0.7444156176578948, 0.8163594963421051],
[0.7446515092333335, 0.16480170130000002],
[0.41286762617741934, 0.8339854567580643],
[0.7270511662727274, 0.8879601891818183],
[0.38520599129896915, 0.6855210755979384],
[0.7592201110392157, 0.7585493956078432],
[0.49039547527118654, 0.7361362472542373],
[0.9117973523888888, 0.21051081468518523],
[1.0584204511063833, 0.2904019457021277]]
centroids10_1 = [row[0] for row in centroids10]
centroids10_2 = [row[1] for row in centroids10]

centroids15 = [[0.7529697456956523, 0.7966391326956521],
[0.45792718186111103, 0.6931821757777779],
[0.412470149547619, 0.8545508465714288],
[0.7631032588421052, 0.1812678274473684],
[0.36117167694915275, 0.7285032277796609],
[0.5713681434545455, 0.7401351843636362],
[0.7852959763571429, 0.67070509175],
[0.8034321340000001, 0.7369012196],
[0.9299890479117646, 0.181487767],
[0.7317714465238095, 0.7439763988571428],
[1.1104990099999998, 0.31052180395652174],
[0.4035721931666666, 0.6213977209666666],
[0.976759300361111, 0.2711045407777778],
[0.7299715703225806, 0.8748411622903227],
[0.45964094697500013, 0.7755969565]]
centroids15_1 = [row[0] for row in centroids15]
centroids15_2 = [row[1] for row in centroids15]

centroids20 = [[0.4173356685208332, 0.8493027741041669],
[0.8379412270000002, 0.6786678626],
[1.1148037636190478, 0.3155065681904762],
[0.7633560366666665, 0.6932074378888889],
[0.4138934025853659, 0.6336424085853657],
[0.7095632301538461, 0.7348652257692309],
[0.7342088900714288, 0.9017703904285713],
[0.7446515092333335, 0.16480170130000002],
[0.6504008864444444, 0.8397434824444444],
[0.7712558736428573, 0.7669343271785714],
[0.3626835846557379, 0.7300813642950819],
[0.7545210640833333, 0.8339565860833335],
[0.7769452283333335, 0.6568584831666667],
[0.8117818634545454, 0.7427277961818182],
[0.73426175, 0.7921531697142858],
[0.7995436256666667, 0.60030189],
[0.9034414611666666, 0.20814560189583334],
[0.47530848881250004, 0.7374906065625],
[1.0064609080937499, 0.26249526931250006],
[0.7940089277500001, 0.695114312]]
centroids20_1 = [row[0] for row in centroids20]
centroids20_2 = [row[1] for row in centroids20]

# %%
plt.figure(figsize=(10,10))
plt.plot(coord1, coord2, '.', color = '0.75', label='true data')
plt.plot(centroids2_1, centroids2_2, 'bx', label = 'k=2')
plt.plot(centroids3_1, centroids3_2, 'r.', label = 'k=3')
plt.plot(centroids5_1, centroids5_2, 'go', label = 'k=5')
plt.plot(centroids10_1, centroids10_2, 'c*', label = 'k=10')
plt.plot(centroids15_1, centroids15_2, 'm+', label = 'k=15')
plt.plot(centroids20_1, centroids20_2, 'y.', label = 'k=20')
plt.title("Lloyd k means clustering")
plt.legend()
plt.xlim(0,1.3)
plt.ylim(0,1.3)
plt.show()

# %%
plt.clf()

# %%
centroidsall = [[0.757555239751634, 0.7718910351437905],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.757555239751634, 0.7718910351437905],
[0.9261249122748091, 0.22870630900763358],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.757555239751634, 0.7718910351437905],
[0.41989432122685194, 0.7413268816342596],
[0.757555239751634, 0.7718910351437905],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.757555239751634, 0.7718910351437905],
[0.757555239751634, 0.7718910351437905],
[0.9261249122748091, 0.22870630900763358],
[0.41989432122685194, 0.7413268816342596],
[0.41989432122685194, 0.7413268816342596],
[0.757555239751634, 0.7718910351437905],
[0.9261249122748091, 0.22870630900763358],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.757555239751634, 0.7718910351437905],
[0.757555239751634, 0.7718910351437905],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.9261249122748091, 0.22870630900763358],
[0.757555239751634, 0.7718910351437905],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.41989432122685194, 0.7413268816342596],
[0.757555239751634, 0.7718910351437905],
[0.757555239751634, 0.7718910351437905],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.41989432122685194, 0.7413268816342596],
[0.757555239751634, 0.7718910351437905],
[0.9261249122748091, 0.22870630900763358],
[0.41989432122685194, 0.7413268816342596],
[0.757555239751634, 0.7718910351437905],
[0.9261249122748091, 0.22870630900763358],
[0.757555239751634, 0.7718910351437905],
[0.9261249122748091, 0.22870630900763358],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.757555239751634, 0.7718910351437905],
[0.41989432122685194, 0.7413268816342596],
[0.41989432122685194, 0.7413268816342596],
[0.757555239751634, 0.7718910351437905],
[0.9261249122748091, 0.22870630900763358],
[0.757555239751634, 0.7718910351437905],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.9261249122748091, 0.22870630900763358],
[0.41989432122685194, 0.7413268816342596],
[0.757555239751634, 0.7718910351437905],
[0.559900067932249, 0.753999823333333],
[1.0327437650153846, 0.2665040852461539],
[0.8211214966969695, 0.19148122634848488]]
centroidsall_1 = [row[0] for row in centroidsall]
centroidsall_2 = [row[1] for row in centroidsall]

# %%
plt.figure(figsize=(10,10))
plt.plot(coord1, coord2, '.', color = '0.75', label='true data')
plt.plot(centroidsall_1, centroidsall_2, '.',  color = '0.0', label = 'k=3')
plt.title("20 runs Lloyd k means clustering for k=3")
plt.legend()
plt.xlim(0,1.3)
plt.ylim(0,1.3)
plt.show()

# %%
plt.clf()

# %%
centroidsallpp = [[0.559900067932249, 0.753999823333333],
[1.0166932148831165, 0.25573260494805206],
[0.7969812215185181, 0.19016881294444446],
[0.559900067932249, 0.753999823333333],
[0.7969812215185181, 0.19016881294444446],
[1.0166932148831165, 0.25573260494805206],
[0.9261249122748091, 0.22870630900763358],
[0.41989432122685194, 0.7413268816342596],
[0.757555239751634, 0.7718910351437905],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.757555239751634, 0.7718910351437905],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.757555239751634, 0.7718910351437905],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.757555239751634, 0.7718910351437905],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.757555239751634, 0.7718910351437905],
[0.9261249122748091, 0.22870630900763358],
[0.757555239751634, 0.7718910351437905],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.757555239751634, 0.7718910351437905],
[0.41989432122685194, 0.7413268816342596],
[0.757555239751634, 0.7718910351437905],
[0.9261249122748091, 0.22870630900763358],
[0.41989432122685194, 0.7413268816342596],
[0.559900067932249, 0.753999823333333],
[0.8211214966969695, 0.19148122634848488],
[1.0327437650153846, 0.2665040852461539],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.757555239751634, 0.7718910351437905],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.757555239751634, 0.7718910351437905],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.757555239751634, 0.7718910351437905],
[1.0166932148831165, 0.25573260494805206],
[0.559900067932249, 0.753999823333333],
[0.7969812215185181, 0.19016881294444446],
[0.9261249122748091, 0.22870630900763358],
[0.41989432122685194, 0.7413268816342596],
[0.757555239751634, 0.7718910351437905],
[0.757555239751634, 0.7718910351437905],
[0.9261249122748091, 0.22870630900763358],
[0.41989432122685194, 0.7413268816342596],
[0.559900067932249, 0.753999823333333],
[1.0166932148831165, 0.25573260494805206],
[0.7969812215185181, 0.19016881294444446],
[0.9261249122748091, 0.22870630900763358],
[0.41989432122685194, 0.7413268816342596],
[0.757555239751634, 0.7718910351437905],
[0.41989432122685194, 0.7413268816342596],
[0.9261249122748091, 0.22870630900763358],
[0.757555239751634, 0.7718910351437905]]
centroidsallpp_1 = [row[0] for row in centroidsallpp]
centroidsallpp_2 = [row[1] for row in centroidsallpp]

# %%
plt.figure(figsize=(10,10))
plt.plot(coord1, coord2, '.', color = '0.75', label='true data')
plt.plot(centroidsallpp_1, centroidsallpp_2, '.',  color = '0.0', label = 'k=3')
plt.title("20 runs k-means++ clustering for k=3")
plt.legend()
plt.xlim(0,1.3)
plt.ylim(0,1.3)
plt.show()
